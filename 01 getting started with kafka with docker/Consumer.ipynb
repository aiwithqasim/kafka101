# %%
from kafka import KafkaConsumer
import json

# %%
from kafka import KafkaConsumer
import json

# Define Kafka consumer
consumer = KafkaConsumer(
    'test-topic',  # The topic to consume messages from
    bootstrap_servers=['localhost:9092'],  # List of Kafka brokers to connect to
    auto_offset_reset='earliest',  # Where to start reading messages when no offset is stored ('earliest' to read from the beginning)
    enable_auto_commit=True,  # Automatically commit offsets after consuming messages
    value_deserializer=lambda x: x.decode('utf-8') if x else None  # Deserialize message values from bytes to UTF-8 strings
)

# Consume messages with error handling for non-JSON messages
for message in consumer:
    print(message.value)
# Out:
# Hello from Kafka
# Qasim Hassan this side
# {"key": "Qasim Hassan", "value": "Hello, Kafka!"}
# {"key": "Qasim Hassan", "value": "Hello, Kafka!"}
# {"key": "value-0", "partition": 0}
# {"key": "value-0", "message": "Message 0"}
# {"key": "value-1", "message": "Message 1"}
# {"key": "value-2", "message": "Message 2"}
# {"key": "value-3", "message": "Message 3"}
# {"key": "value-4", "message": "Message 4"}
# {"key": "value-5", "message": "Message 5"}
# {"key": "value-6", "message": "Message 6"}
# {"key": "value-7", "message": "Message 7"}
# {"key": "value-8", "message": "Message 8"}
# {"key": "value-9", "message": "Message 9"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#       5 consumer = KafkaConsumer(
#       6     'test-topic',  # The topic to consume messages from
#       7     bootstrap_servers=['localhost:9092'],  # List of Kafka brokers to connect to
#    (...)     10     value_deserializer=lambda x: x.decode('utf-8') if x else None  # Deserialize message values from bytes to UTF-8 strings
#      11 )
#      13 # Consume messages with error handling for non-JSON messages
# ---> 14 for message in consumer:
#      15     print(message.value)
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\consumer\group.py:1203, in KafkaConsumer.__next__(self)
#    1201     return self.next_v1()
#    1202 else:
# -> 1203     return self.next_v2()
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\consumer\group.py:1211, in KafkaConsumer.next_v2(self)
#    1209     self._iterator = self._message_generator_v2()
#    1210 try:
# -> 1211     return next(self._iterator)
#    1212 except StopIteration:
#    1213     self._iterator = None
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\consumer\group.py:1126, in KafkaConsumer._message_generator_v2(self)
#    1124 def _message_generator_v2(self):
#    1125     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1126     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1127     for tp, records in record_map.items():
#    1128         # Generators are stateful, and it is possible that the tp / records
#    1129         # here may become stale during iteration -- i.e., we seek to a
#    1130         # different offset, pause consumption, or lose assignment.
#    1131         for record in records:
#    1132             # is_fetchable(tp) should handle assignment changes and offset
#    1133             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1134             # outer function destroying the existing iterator/generator
#    1135             # via self._iterator = None
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\consumer\group.py:663, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     661 remaining = timeout_ms
#     662 while not self._closed:
# --> 663     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     664     if records:
#     665         return records
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\consumer\group.py:712, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     709     self._client.poll(timeout_ms=0)
#     711 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 712 self._client.poll(timeout_ms=timeout_ms)
#     713 # after the long poll, we should check whether the group needs to rebalance
#     714 # prior to returning data so that the group can stabilize faster
#     715 if self._coordinator.need_rejoin():
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\client_async.py:601, in KafkaClient.poll(self, timeout_ms, future)
#     598             timeout = min(timeout, self.config['retry_backoff_ms'])
#     599         timeout = max(0, timeout)  # avoid negative timeouts
# --> 601     self._poll(timeout / 1000)
#     603 # called without the lock to avoid deadlock potential
#     604 # if handlers need to acquire locks
#     605 responses.extend(self._fire_pending_completed_requests())
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\site-packages\kafka\client_async.py:633, in KafkaClient._poll(self, timeout)
#     630 self._register_send_sockets()
#     632 start_select = time.time()
# --> 633 ready = self._selector.select(timeout)
#     634 end_select = time.time()
#     635 if self._sensors:
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\selectors.py:314, in SelectSelector.select(self, timeout)
#     312 ready = []
#     313 try:
# --> 314     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     315 except InterruptedError:
#     316     return ready
#
# File c:\Users\QasimHassan\AppData\Local\Programs\Python\Python314\Lib\selectors.py:305, in SelectSelector._select(self, r, w, _, timeout)
#     304 def _select(self, r, w, _, timeout=None):
# --> 305     r, w, x = select.select(r, w, w, timeout)
#     306     return r, w + x, []
#
# KeyboardInterrupt:

# %%
# Define Kafka consumer
consumer = KafkaConsumer(
    'test-topic',
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    value_deserializer=lambda x: x.decode('utf-8') if x else None
)

# Consume messages and print partition and offset
count = 0
for message in consumer:
    print(f"Consumed message: {message.value}")
    print(f"Partition: {message.partition}, Offset: {message.offset}")
    print("---")
    count += 1
    if count >= 10:  # Stop after consuming 10 messages
        break

consumer.close()
print("Consumer closed successfully!")
# Out:
# Consumed message: Hello from Kafka
# Partition: 0, Offset: 0
# ---
# Consumed message: Qasim Hassan this side
# Partition: 0, Offset: 1
# ---
# Consumed message: {"key": "Qasim Hassan", "value": "Hello, Kafka!"}
# Partition: 0, Offset: 2
# ---
# Consumed message: {"key": "Qasim Hassan", "value": "Hello, Kafka!"}
# Partition: 0, Offset: 3
# ---
# Consumed message: {"key": "value-0", "partition": 0}
# Partition: 0, Offset: 4
# ---
# Consumed message: {"key": "value-0", "message": "Message 0"}
# Partition: 0, Offset: 5
# ---
# Consumed message: {"key": "value-1", "message": "Message 1"}
# Partition: 0, Offset: 6
# ---
# Consumed message: {"key": "value-2", "message": "Message 2"}
# Partition: 0, Offset: 7
# ---
# Consumed message: {"key": "value-3", "message": "Message 3"}
# Partition: 0, Offset: 8
# ---
# Consumed message: {"key": "value-4", "message": "Message 4"}
# Partition: 0, Offset: 9
# ---
# Consumer closed successfully!
